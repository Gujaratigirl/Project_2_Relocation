# %%
# Import Dependencies
import pandas as pd
import os

# %%
file_path = os.path.join("Data", "state_migrations_2019.xlsx")
df = pd.read_excel(file_path, header=0)
df
# Out:
#             Current_State  Pop_1plus_yrs  Same_house_1yrago  \
# 0           United States      324665523          280343146
# 1                 Alabama        4849509            4197698
# 2                  Alaska         722063             609362
# 3                 Arizona        7200620            6038776
# 4                Arkansas        2989054            2559444
# 5              California       39084048           34394220
# 6                Colorado        5701658            4695821
# 7             Connecticut        3531986            3106754
# 8                Delaware         964817             843383
# 9   District of Columbia          697556             563798
# 10                Florida       21269409           18083185
# 11                Georgia       10499808            9034705
# 12                 Hawaii        1396819            1215974
# 13                  Idaho        1764327            1478739
# 14               Illinois       12536539           11014059
# ...

# %%
states = ["California", "Florida", "Indiana", "North Carolina", "Texas"]

states_df = df.loc[(df["Current_State"] == states[0]) | (df["Current_State"] == states[1]) | (df["Current_State"] == states[2]) | (df["Current_State"] == states[3]) | (df["Current_State"] == states[4]), :]
states_df
# Out:
#      Current_State  Pop_1plus_yrs  Same_house_1yrago  Same_state_1yrago  \
# 5       California       39084048           34394220            3943139
# 10         Florida       21269409           18083185            2381208
# 15         Indiana        6656971            5735703             743092
# 34  North Carolina       10371906            8834381            1170200
# 44           Texas       28642658           24347958            3517954
#
#     Diff_state_1yrago_total  Alabama-1yrago  Alaska-1yrago  Arizona-1yrago  \
# 5                    480204          3310.0         5064.0         28226.0
# 10                   601611         15153.0         4906.0          7054.0
# 15                   151443          1481.0          184.0          4067.0
# 34                   315215          4697.0         1568.0          5319.0
# 44                   559661          8791.0         4622.0         21205.0
#
#     Arkansas-1yrago  California-1yrago  ...  Vermont-1yrago  Virginia-1yrago  \
# ...

# %%
stacked_df = states_df.stack()
stacked_df
# Out:
# 5   Current_State              California
#     Pop_1plus_yrs                39084048
#     Same_house_1yrago            34394220
#     Same_state_1yrago             3943139
#     Diff_state_1yrago_total        480204
#                                   ...
# 44  Wyoming-1yrago                   1311
#     Total-1yrago                   217085
#     Puerto_Rico-1yrago               9352
#     US_Island_Area-1yrago             371
#     Foreign-1yrago                 207362
# Length: 295, dtype: object

# %%
stacked_df.loc["Current_State" = ]
